# %%
from seleniumwire import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium.webdriver.chrome.options import Options

# %%
scrape_url = "https://www.tripadvisor.in/Attraction_Review-g297685-d319858-Reviews-Ganges_River-Varanasi_Varanasi_District_Uttar_Pradesh.html"

# %%
data = []

# %%
# pip install requests
import requests

#proxy = "http://3d966d92eee395deaf1ab6c83ce5fca93bec91f6:premium_proxy=true@proxy.zenrows.com:8001"
proxy = "http://bf468f326d6ae92e70be440845041113f929d8ff:premium_proxy=true@proxy.zenrows.com:8001"
options = {"proxy":{"http": proxy, "https": proxy}}

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# Create an instance of ChromeOptions
options = Options()

# Add the proxy to the options object
options.add_argument('--proxy-server=http://bf468f326d6ae92e70be440845041113f929d8ff:premium_proxy=true@proxy.zenrows.com:8001')
# Create the webdriver with the specified options
driver = webdriver.Chrome(options=options)

# %%
#del reviews[0]
for review in reviews:

    body = review.find("div", class_="biGQs _P pZUbB KxBGd")
    name = review.find("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")
    url = review.find("div",class_="biGQs _P fiohW qWPrE ncFvv fOtGX")
    profile_contribution = review.find("div", class_="biGQs _P pZUbB osNWb")
    contribution = profile_contribution.find("span",class_="IugUm").text
    review_url = url.find("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")['href']
    review_heading = url.find("span", class_='yCeTE')
    date = review.find("div", class_="biGQs _P pZUbB ncFvv osNWb")
    date_category = review.find("div", class_="RpeCd").text
    travel_date=date_category.split("•")[0]
    category = date_category.split("•")[1]
    rating = review.find("svg", class_="UctUV d H0")['aria-label']
    print("URL: https://www.tripadvisor.ca"+review_url)
    print("Reviewer name:",name.text)
    print("Profile Contribution:",contribution.split("•")[0])
    print("Review Heading:",review_heading.text)
    print("Review Body:",body.text)
    print("Review Date:",date.text)
    print("Rating:",rating)
    print("Travelled on:", travel_date)
    print("Category:",category)
    print("\n\n")
# Out:
# URL: https://www.tripadvisor.ca/ShowUserReviews-g297685-d319858-r936580339-Ganges_River-Varanasi_Varanasi_District_Uttar_Pradesh.html
# Reviewer name: Ram Gautam
# Profile Contribution: 971 contributions
# Review Heading: Greedy boatmen and boat with no fuel
# ...

# %%
import csv

# Specify the CSV file path
csv_file_path = "ganges.csv"



# Check if the CSV file already exists, if not, create it with headers
try:
    with open(csv_file_path, 'x', newline='') as csv_file:
        fieldnames = ["name","url","review_score","review_heading","profile_contr","review_body","date_of_stay","company"]
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
except FileExistsError:
    pass

# %%
def extract_reviews(url, total):
    options.add_argument('--proxy-server=http://bf468f326d6ae92e70be440845041113f929d8ff:premium_proxy=true@proxy.zenrows.com:8001')
    # Create the webdriver with the specified options
    driver = webdriver.Chrome(options=options)
    count = 0
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    reviews = soup.find_all("div", class_="_c")
    del reviews[0]
    for review in reviews:
        count=count+1
        print("Review Number:",count)
        body = review.find("div", class_="biGQs _P pZUbB KxBGd")
        name = review.find("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")
        url = review.find("div",class_="biGQs _P fiohW qWPrE ncFvv fOtGX")
        profile_contribution = review.find("div", class_="biGQs _P pZUbB osNWb")
        #print("profile: ",profile_contribution)
        contribution = profile_contribution.find_all("span")
        if len(contribution)>1:
            profile_contribution = contribution[1].text
        else:
            profile_contribution = contribution[0].text
        review_url = url.find("a", class_="BMQDV _F Gv wSSLS SwZTJ FGwzt ukgoS")['href']
        review_heading = url.find("span", class_='yCeTE')
        date = review.find("div", class_="biGQs _P pZUbB ncFvv osNWb")
        date_category = review.find("div", class_="RpeCd").text
        splitted = date_category.split("•")
        if len(splitted)>1:
            travel_date=splitted[0]
            category=splitted[1]
        else:
            travel_date=splitted[0]
            category=" "
        #travel_date=date_category.split("•")[0]
        #category = date_category.split("•")[1]
        rating = review.find("svg", class_="UctUV d H0")['aria-label']
        final_url="https://www.tripadvisor.ca"+review_url
        print("URL: ",final_url)
        print("Reviewer name:",name.text)
        print("Profile Contribution:",profile_contribution)
        print("Review Heading:",review_heading.text)
        print("Review Body:",body.text)
        print("Review Date:",date.text)
        print("Rating:",rating)
        print("Travelled on and category:", travel_date)
        print("Category:",category)
        print("\n\n")
        with open('ganges.csv', 'a', encoding='utf-8', newline='') as csv_file:
            
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            if csv_file.tell() == 0:
                # Write the header if the file is empty
                writer.writeheader()
            #writer.writeheader()
            writer.writerow({
                "name": name.text,
                "url": final_url,
                "review_score": rating,
                "review_heading": review_heading.text,
                "profile_contr": profile_contribution,
                "review_body": body.text,
                "date_of_stay": travel_date,
                "company": category
            })

            # Write the review data
            #writer.writerow({"name":name.text,"url":final_url,"review_score":rating,"review_heading":review_heading.text,"profile_contr":profile_contribution,"review_body":body.text,"date_of_stay":travel_date,"company":category})

        print("Review has been added to the CSV file.")
        
    total = total+count
    if(total==40):
        return
    next_page = soup.find_all("a", class_="BrOJk u j z _F wSSLS tIqAi unMkR")
    print(next_page, len(next_page))
    if len(next_page)>=2:
        next_url = 'https://www.tripadvisor.in'+next_page[1]['href']
        extract_reviews(next_url,total)
    else:
        next_url = 'https://www.tripadvisor.in'+next_page[0]['href']
        extract_reviews(next_url,total)

# %%
total=0

# %%
extract_reviews("https://www.tripadvisor.in/Attraction_Review-g297685-d319858-Reviews-or30-Ganges_River-Varanasi_Varanasi_District_Uttar_Pradesh.html",0)
# Out:
# Review Number: 1
# URL:  https://www.tripadvisor.ca/ShowUserReviews-g297685-d319858-r844854523-Ganges_River-Varanasi_Varanasi_District_Uttar_Pradesh.html
# Reviewer name: Bellab F
# Profile Contribution: 3 contributions
# Review Heading: The most filthy water way in the world!
# Review Body: I was shocked to see a river that is so treasured and worshiped as disgusting as it could ever get! I imagine up further where it begins would be a lot better but what I saw was a total disgrace! Human and animal waste was everywhere and the amount of rubbish was unbelievable! I even saw a dead bloated body float past! I can not believe anyone worships this river at all or they just don’t care! I couldn’t even take a deep breath with the stench!
# Review Date: Written 27 June 2022
# Rating: 1.0 of 5 bubbles
# Travelled on and category: Jan 2022
# Category:
#
#
#
# Review has been added to the CSV file.
# Review Number: 2
# ...

# %%
`
